# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # RF_RFE

# %%
n_feature = [50, 70, 90, 110, 130, 150, 170, 190, 210, 230, 250, 270, 290, 310, 330, 350, 370, 390, 410, 430, 450, 470, 490, 510, 530]
auc = [0.43229166666666663, 0.4348958333333333, 0.5442708333333334, 0.5703125, 0.4921875, 0.44010416666666674, 0.45572916666666663, 0.5052083333333334, 0.5911458333333333, 0.46875, 0.43489583333333337, 0.5182291666666667, 0.46354166666666674, 0.4296875, 0.4765625, 0.5520833333333333, 0.4765625, 0.6328125, 0.45833333333333337, 0.5572916666666667, 0.5729166666666666, 0.484375, 0.5703125, 0.6328125, 0.5625]
accuracy = [0.39285714285714285, 0.42857142857142855, 0.42857142857142855, 0.5, 0.5, 0.42857142857142855, 0.4642857142857143, 0.5, 0.5, 0.4642857142857143, 0.4642857142857143, 0.5357142857142857, 0.4642857142857143, 0.42857142857142855, 0.4642857142857143, 0.5, 0.42857142857142855, 0.42857142857142855, 0.42857142857142855, 0.4642857142857143, 0.4642857142857143, 0.39285714285714285, 0.39285714285714285, 0.5357142857142857, 0.5714285714285714]
recall = [0.9166666666666666, 0.8333333333333334, 0.75, 0.75, 0.8333333333333334, 0.75, 0.9166666666666666, 0.75, 0.8333333333333334, 0.75, 0.9166666666666666, 0.8333333333333334, 0.75, 0.9166666666666666, 0.9166666666666666, 0.6666666666666666, 0.75, 0.6666666666666666, 0.75, 0.6666666666666666, 0.9166666666666666, 0.6666666666666666, 0.9166666666666666, 0.8333333333333334, 0.5833333333333334]

# %%
max_auc = max(auc)
index = auc.index(max_auc)
print(max_auc)
print(index)
print(n_feature[index])
# Out:
# 0.6328125
# 17
# 390

# %%
# AUC
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('AUC')
plt.title('RF_RFE AUC')
plt.bar(n_feature, auc, width = 6, color='green')
plt.show()

# %%
# Accuracy
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Accuracy')
plt.title('RF_RFE Accuracy')
plt.bar(n_feature, accuracy, width = 6, color='green')
plt.title
plt.show()

# %%
# Recall
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Recall')
plt.title('RF_RFE Recall')
plt.bar(n_feature, recall, width = 6, color='green')
plt.show()

# %% [markdown]
# # SVM_RFE

# %%
n_feature = [50, 70, 90, 110, 130, 150, 170, 190, 210, 230, 250, 270, 290, 310, 330, 350, 370, 390, 410, 430, 450, 470, 490, 510, 530]
auc_arr = [0.34375, 0.3072916666666667, 0.28125, 0.3333333333333333, 0.3541666666666667, 0.34895833333333337, 0.359375, 0.359375, 0.3125, 0.3020833333333333, 0.3020833333333333, 0.28125, 0.2864583333333333, 0.28645833333333337, 0.296875, 0.3020833333333333, 0.3020833333333333, 0.296875, 0.3072916666666667, 0.3072916666666667, 0.3072916666666667, 0.3072916666666667, 0.3072916666666667, 0.3072916666666667, 0.3072916666666667]
accuracy_arr = [0.42857142857142855, 0.39285714285714285, 0.39285714285714285, 0.42857142857142855, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143]
recall_arr = [0.75, 0.8333333333333334, 0.75, 0.6666666666666666, 0.8333333333333334, 0.8333333333333334, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75, 0.75]

# %%
max_auc = max(auc_arr)
index = auc_arr.index(max_auc)
print(max_auc)
print(index)
print(n_feature[index])
# Out:
# 0.359375
# 6
# 170

# %%
# AUC
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('AUC')
plt.title('SVM_RFE AUC')
plt.bar(n_feature, auc_arr, width = 6, color='blue')
plt.show()

# %%
# Accuracy
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Accuracy')
plt.title('SVM_RFE Accuracy')
plt.bar(n_feature, accuracy_arr, width = 6, color='blue')
plt.title
plt.show()

# %%
# Recall
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Recall')
plt.title('SVM_RFE Recall')
plt.bar(n_feature, recall_arr, width = 6, color='blue')
plt.show()

# %% [markdown]
# # Logistic

# %%
n_feature_to_select_arr = [476, 428, 307, 274, 222, 204, 144, 133, 123, 97]
auc_arr = [0.40625, 0.41145833333333337, 0.421875, 0.42708333333333337, 0.4375, 0.4322916666666667, 0.4427083333333333, 0.4427083333333333, 0.453125, 0.4583333333333333]
accuracy_arr = [0.4642857142857143, 0.5, 0.5, 0.4642857142857143, 0.4642857142857143, 0.4642857142857143, 0.5, 0.5357142857142857, 0.5357142857142857, 0.5357142857142857]
recall_arr = [0.3333333333333333, 0.4166666666666667, 0.4166666666666667, 0.4166666666666667, 0.4166666666666667, 0.4166666666666667, 0.5, 0.5, 0.5, 0.5]

# %%
max_auc = max(auc_arr)
index = auc_arr.index(max_auc)
print(max_auc)
print(index)
print(n_feature_to_select_arr[index])
# Out:
# 0.4583333333333333
# 9
# 97

# %%
# AUC
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('AUC')
plt.title('Logistic AUC')
plt.bar(n_feature_to_select_arr, auc_arr, width = 6, color='orange')
plt.show()

# %%
# Accuracy
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Accuracy')
plt.title('Logistic Accuracy')
plt.bar(n_feature_to_select_arr, accuracy_arr, width = 6, color='orange')
plt.title
plt.show()

# %%
# Recall
plt.clf()
plt.cla()
plt.xlabel('n_feature')
plt.ylabel('Recall')
plt.title('Logistic Recall')
plt.bar(n_feature_to_select_arr, recall_arr, width = 6, color='orange')
plt.show()
